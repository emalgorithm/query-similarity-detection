# %%
from util import get_balanced_data
from word2vec import Word2Vec
from glove_synonyms import GloveSynonyms
from adversarial_algos import adversarial_white_box_change
from kaggle_model import KaggleModel
from text_processor import TextProcessor

# %load_ext autoreload

# %autoreload 2
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = KaggleModel()

# %%
model.predict_single('How good is los angeles?', 'How great is los angeles?')
# Out:
# array([[0.78506786]], dtype=float32)

# %%
X_train, X_test, y_train, y_test = get_balanced_data()
# Out:
# We have 298526 positive samples
# We have 298526 negative samples

# %%
w2v = Word2Vec()

# %%
glove = GloveSynonyms()
# Out:
# Loading Glove Model
# Done. 65713  words loaded!

# %%
tp = TextProcessor()

# %%
glove.most_similar('bad', n=5)
# Out:
# ['inclement', 'mala', 'naughty', 'rotten', 'amiss']

# %%
for i in range(100):
    q1 = X_test[i, 0]
    q2 = X_test[i, 1]
    if model.predict_single(q1, q2) > 0.6:
        adversarial_white_box_change(q1, q2, model, tp, glove)
        print()
# Out:
# initial q1: What is the best way to stay active?
# initial q2: How do I always stay active?
# Initial similarity is [[0.62797105]]
# UNSUCCESSFULL
#
# initial q1: What open source project did you start contributing with?
# initial q2: How could start with open source development?
# Initial similarity is [[0.93257207]]
#
# q1: 'What open source project did you start contributing with?'
# q2: 'How did start with open source development?'
# Replacing 1 words we have a similarity of [[0.87304926]]
#
# q1: 'What open source project did you start contributing with?'
# q2: 'How ai start with open source development?'
# Replacing 2 words we have a similarity of [[0.6565293]]
#
# q1: 'What open source project did you start contributing with?'
# q2: 'How ai starting with open source development?'
# Replacing 3 words we have a similarity of [[0.4495115]]
#
# q1: 'What open source project did you start contributing with?'
# q2: 'How ai starting with opens source development?'
# Replacing 4 words we have a similarity of [[0.34212333]]
#
# initial q1: What would the world be like if the Nazi Germany had won WW2?
# initial q2: What would have happened if Germany had won WWII?
# Initial similarity is [[0.76112914]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'What would have happened if Germany had triumphed WWII?'
# Replacing 1 words we have a similarity of [[0.4608695]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'What would have happened if Germany ha triumphed WWII?'
# Replacing 2 words we have a similarity of [[0.36838147]]
#
# initial q1: Is watching porn a sin?
# initial q2: Is watching porn sin?
# Initial similarity is [[0.84408516]]
#
# q1: 'Is watching porn a sin?'
# q2: 'Is watching porn oin?'
# Replacing 1 words we have a similarity of [[0.37979499]]
#
# initial q1: What is the best 2 liner you know of a shayari?
# initial q2: What are the 2 best lines of poetry or Shayari?
# Initial similarity is [[0.8125659]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are the 2 best lines of verse or Shayari?'
# Replacing 1 words we have a similarity of [[0.64248234]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are the 2 better lines of verse or Shayari?'
# Replacing 2 words we have a similarity of [[0.6169857]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are the 2 improved lines of verse or Shayari?'
# Replacing 3 words we have a similarity of [[0.40996858]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are the 2 improved lines of verse orr Shayari?'
# Replacing 4 words we have a similarity of [[0.3298817]]
#
# initial q1: Is the 2016 MacBook Pro with Touch Bar a worthy buy?
# initial q2: What is your review of the MacBook Pro (2016)?
# Initial similarity is [[0.95964915]]
#
# q1: 'Is the 2016 MacBook Pro with Touch Bar a worthy buy?'
# q2: 'What is ton review of the MacBook Pro (2016)?'
# Replacing 1 words we have a similarity of [[0.9359583]]
#
# q1: 'Is the 2016 MacBook Pro with Touch Bar a worthy buy?'
# q2: 'What is ton review du the MacBook Pro (2016)?'
# Replacing 2 words we have a similarity of [[0.9084315]]
# UNSUCCESSFULL
#
# initial q1: What are some furniture & House removalists for relocating my business?
# initial q2: What are some furniture removalists for relocating my business?
# Initial similarity is [[0.9439171]]
#
# q1: 'What are some furniture & House removalists for relocating my business?'
# q2: 'What are some movable removalists for relocating my business?'
# Replacing 1 words we have a similarity of [[0.82649535]]
#
# q1: 'What are some furniture & House removalists for relocating my business?'
# q2: 'What are some moveable removalists for relocating my business?'
# Replacing 2 words we have a similarity of [[0.63460416]]
#
# q1: 'What are some furniture & House removalists for relocating my business?'
# q2: 'What be some moveable removalists for relocating my business?'
# Replacing 3 words we have a similarity of [[0.48334455]]
#
# q1: 'What are some furniture & House removalists for relocating my business?'
# q2: 'What be certain moveable removalists for relocating my business?'
# Replacing 4 words we have a similarity of [[0.3592692]]
#
# initial q1: How can I improve my pronunciation of English words?
# initial q2: How can I improve English speaking skill?
# Initial similarity is [[0.9852704]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'How can I improve English speaking skills?'
# Replacing 1 words we have a similarity of [[0.97680515]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'How can I improve English speaks skills?'
# Replacing 2 words we have a similarity of [[0.97495496]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'How can I improve English talking skills?'
# Replacing 3 words we have a similarity of [[0.96674937]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'How kan I improve English talking skills?'
# Replacing 4 words we have a similarity of [[0.94320387]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'How kansas I improve English talking skills?'
# Replacing 5 words we have a similarity of [[0.8482859]]
# UNSUCCESSFULL
#
# initial q1: What's the best coffee?
# initial q2: What is the best coffee to drink?
# Initial similarity is [[0.757521]]
#
# q1: 'What's the best coffee?'
# q2: 'What is du best coffee to drink?'
# Replacing 1 words we have a similarity of [[0.30132687]]
#
# initial q1: Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?
# initial q2: What are the chances of a nuclear war between India and Pakistan?
# Initial similarity is [[0.9578176]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the chances of a nuclear war among India and Pakistan?'
# Replacing 1 words we have a similarity of [[0.9332179]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the chances of a nuclear warfare among India and Pakistan?'
# Replacing 2 words we have a similarity of [[0.8261411]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the opportunity of a nuclear warfare among India and Pakistan?'
# Replacing 3 words we have a similarity of [[0.7042488]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the opportunity of a nuke warfare among India and Pakistan?'
# Replacing 4 words we have a similarity of [[0.6005868]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the opportunity of a warhead warfare among India and Pakistan?'
# Replacing 5 words we have a similarity of [[0.3911616]]
#
# initial q1: Are the IMDB ratings accurate?
# initial q2: Is IMDb rating apt?
# Initial similarity is [[0.93939286]]
#
# q1: 'Are the IMDB ratings accurate?'
# q2: 'Is IMDb ratings apt?'
# Replacing 1 words we have a similarity of [[0.91727877]]
#
# q1: 'Are the IMDB ratings accurate?'
# q2: 'Is IMDb ratings likely?'
# Replacing 2 words we have a similarity of [[0.89891785]]
# UNSUCCESSFULL
#
# initial q1: Where is the best videocon service center in Hyderabad?
# initial q2: Which is the best Videocon Service Center in Hyderabad?
# Initial similarity is [[0.7097009]]
#
# q1: 'Where is the best videocon service center in Hyderabad?'
# q2: 'Which is the better Videocon Service Center in Hyderabad?'
# Replacing 1 words we have a similarity of [[0.672739]]
#
# q1: 'Where is the best videocon service center in Hyderabad?'
# q2: 'Which is du better Videocon Service Center in Hyderabad?'
# Replacing 2 words we have a similarity of [[0.40373978]]
#
# q1: 'Where is the best videocon service center in Hyderabad?'
# q2: 'Which is du improved Videocon Service Center in Hyderabad?'
# Replacing 3 words we have a similarity of [[0.25129575]]
#
# initial q1: How can Donald Trump win the elections when people hate him so much?
# initial q2: How did Donald Trump win the 2016 Presidential Election?
# Initial similarity is [[0.83445764]]
#
# q1: 'How can Donald Trump win the elections when people hate him so much?'
# q2: 'How did Donald Trump win du 2016 Presidential Election?'
# Replacing 1 words we have a similarity of [[0.54982954]]
# q1: 'How can Donald Trump win the elections when people hate him so much?'
# q2: 'How ai Donald Trump win du 2016 Presidential Election?'
# Replacing 2 words we have a similarity of [[0.2157931]]
#
# initial q1: Do heaven and hell really exist?
# initial q2: Is hell and heaven real?
# Initial similarity is [[0.8519228]]
#
# q1: 'Do heaven and hell really exist?'
# q2: 'Is hell und heaven real?'
# Replacing 1 words we have a similarity of [[0.22650531]]
#
# initial q1: What are the best way to promote the Atithi dewo Bhawa Campaign in Nepal?
# initial q2: What are the best way to promote the Atithi Dewo Bhawa in Nepal?
# Initial similarity is [[0.7817473]]
#
# q1: 'What are the best way to promote the Atithi dewo Bhawa Campaign in Nepal?'
# q2: 'What are du best way to promote the Atithi Dewo Bhawa in Nepal?'
# Replacing 1 words we have a similarity of [[0.51805604]]
#
# q1: 'What are the best way to promote the Atithi dewo Bhawa Campaign in Nepal?'
# q2: 'What are du best way pour promote the Atithi Dewo Bhawa in Nepal?'
# Replacing 2 words we have a similarity of [[0.41715813]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8071a5479c44> in <module>()
#       3     q2 = X_test[i, 1]
#       4     if model.predict_single(q1, q2) > 0.6:
# ----> 5         adversarial_white_box_change(q1, q2, model, tp, glove)
#       6         print()
#
# ~/src/query-similarity-detection/NLP/Quora Dataset/adversarial_algos.py in adversarial_white_box_change(q1, q2, model, tp, word_similarity, threshold)
#      21         for i, word in enumerate(q2_tokenized):
#      22             if word_similarity.contains_word(word):
# ---> 23                 closest_word = word_similarity.most_similar(word)
#      24                 q2_modified = list(q2_tokenized)
#      25                 q2_modified[i] = closest_word
#
# ~/src/query-similarity-detection/NLP/Quora Dataset/glove_synonyms.py in most_similar(self, word, n)
#      12         distances = (np.dot(self.word_vectors, word_vector)
#      13                        / np.linalg.norm(self.word_vectors, axis=1)
# ---> 14                        / np.linalg.norm(word_vector))
#      15
#      16         idxs = np.argsort(-distances)[1:n+1]
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2284         elif ord is None or ord == 2:
#    2285             # special case for speedup
# -> 2286             s = (x.conj() * x).real
#    2287             return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2288         else:
#
# KeyboardInterrupt:

# %%
for i in range(100):
    q1 = X_test[i, 0]
    q2 = X_test[i, 1]
    if model.predict_single(q1, q2) > 0.6:
        adversarial_white_box_change(q1, q2, model, tp, w2v)
        print()
# Out:
# initial q1: What is the best way to stay active?
# initial q2: How do I always stay active?
# Initial similarity is [[0.62797105]]
#
# q1: 'What is the best way to stay active?'
# q2: 'Why do I always stay active?'
# Replacing 1 words we have a similarity of [[0.165402]]
#
# initial q1: What open source project did you start contributing with?
# initial q2: How could start with open source development?
# Initial similarity is [[0.93257207]]
#
# q1: 'What open source project did you start contributing with?'
# q2: 'How could start with opened source development?'
# Replacing 1 words we have a similarity of [[0.8414253]]
#
# q1: 'What open source project did you start contributing with?'
# q2: 'How could start with opened sources development?'
# Replacing 2 words we have a similarity of [[0.78989995]]
# UNSUCCESSFULL
#
# initial q1: What would the world be like if the Nazi Germany had won WW2?
# initial q2: What would have happened if Germany had won WWII?
# Initial similarity is [[0.76112914]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'What would have happened if Austria had won WWII?'
# Replacing 1 words we have a similarity of [[0.50310856]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which would have happened if Austria had won WWII?'
# Replacing 2 words we have a similarity of [[0.44924062]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which would have happened if Austria have won WWII?'
# Replacing 3 words we have a similarity of [[0.4337776]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which would've happened if Austria have won WWII?'
# Replacing 4 words we have a similarity of [[0.40876618]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which would've happened if Austria've won WWII?'
# Replacing 5 words we have a similarity of [[0.37428564]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which would've happened if Austria've won World_War_II?'
# Replacing 6 words we have a similarity of [[0.20860457]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which would `_ve happened if Austria've won World_War_II?'
# Replacing 7 words we have a similarity of [[0.08420885]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which could `_ve happened if Austria've won World_War_II?'
# Replacing 8 words we have a similarity of [[0.07584825]]
#
# q1: 'What would the world be like if the Nazi Germany had won WW2?'
# q2: 'Which could `_ve happened unless Austria've won World_War_II?'
# Replacing 9 words we have a similarity of [[0.07220425]]
#
# initial q1: Is watching porn a sin?
# initial q2: Is watching porn sin?
# Initial similarity is [[0.84408516]]
#
# q1: 'Is watching porn a sin?'
# q2: 'Is watching porn sins?'
# Replacing 1 words we have a similarity of [[0.7736655]]
#
# q1: 'Is watching porn a sin?'
# q2: 'Is watch porn sins?'
# Replacing 2 words we have a similarity of [[0.74484146]]
# UNSUCCESSFULL
#
# initial q1: What is the best 2 liner you know of a shayari?
# initial q2: What are the 2 best lines of poetry or Shayari?
# Initial similarity is [[0.8125659]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are the 2 best lines of poems or Shayari?'
# Replacing 1 words we have a similarity of [[0.72978765]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are the 3 best lines of poems or Shayari?'
# Replacing 2 words we have a similarity of [[0.70095164]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are this 3 best lines of poems or Shayari?'
# Replacing 3 words we have a similarity of [[0.67594504]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are this 3 best lines of poems either Shayari?'
# Replacing 4 words we have a similarity of [[0.6424955]]
#
# q1: 'What is the best 2 liner you know of a shayari?'
# q2: 'What are this 3 best line of poems either Shayari?'
# Replacing 5 words we have a similarity of [[0.6358111]]
# UNSUCCESSFULL
#
# initial q1: Is the 2016 MacBook Pro with Touch Bar a worthy buy?
# initial q2: What is your review of the MacBook Pro (2016)?
# Initial similarity is [[0.95964915]]
#
# q1: 'Is the 2016 MacBook Pro with Touch Bar a worthy buy?'
# q2: 'What is your review of the MacBook TSX_VENTURE_PRM (2016)?'
# Replacing 1 words we have a similarity of [[0.89374775]]
#
# q1: 'Is the 2016 MacBook Pro with Touch Bar a worthy buy?'
# q2: 'Which is your review of the MacBook TSX_VENTURE_PRM (2016)?'
# Replacing 2 words we have a similarity of [[0.84681547]]
#
# q1: 'Is the 2016 MacBook Pro with Touch Bar a worthy buy?'
# q2: 'Which is your reviewed of the MacBook TSX_VENTURE_PRM (2016)?'
# Replacing 3 words we have a similarity of [[0.8002346]]
# UNSUCCESSFULL
#
# initial q1: What are some furniture & House removalists for relocating my business?
# initial q2: What are some furniture removalists for relocating my business?
# Initial similarity is [[0.9439171]]
#
# q1: 'What are some furniture & House removalists for relocating my business?'
# q2: 'What are some furnishings removalists for relocating my business?'
# Replacing 1 words we have a similarity of [[0.63460416]]
#
# q1: 'What are some furniture & House removalists for relocating my business?'
# q2: 'What are some furnishings removalists for relocating my businesses?'
# Replacing 2 words we have a similarity of [[0.39092568]]
#
# initial q1: How can I improve my pronunciation of English words?
# initial q2: How can I improve English speaking skill?
# Initial similarity is [[0.9852704]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'Why can I improve English speaking skill?'
# Replacing 1 words we have a similarity of [[0.9694295]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'Why can I improve English speaking skills?'
# Replacing 2 words we have a similarity of [[0.9547812]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'Why can I improve English spoke skills?'
# Replacing 3 words we have a similarity of [[0.94894636]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'Why can I improve English talked skills?'
# Replacing 4 words we have a similarity of [[0.9241194]]
#
# q1: 'How can I improve my pronunciation of English words?'
# q2: 'Why can myself improve English talked skills?'
# Replacing 5 words we have a similarity of [[0.88646466]]
# UNSUCCESSFULL
#
# initial q1: What's the best coffee?
# initial q2: What is the best coffee to drink?
# Initial similarity is [[0.757521]]
#
# q1: 'What's the best coffee?'
# q2: 'What is the best coffees to drink?'
# Replacing 1 words we have a similarity of [[0.51041085]]
#
# q1: 'What's the best coffee?'
# q2: 'Which is the best coffees to drink?'
# Replacing 2 words we have a similarity of [[0.39950007]]
#
# initial q1: Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?
# initial q2: What are the chances of a nuclear war between India and Pakistan?
# Initial similarity is [[0.9578176]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the chances of a nuclear war betwen India and Pakistan?'
# Replacing 1 words we have a similarity of [[0.9100348]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the chances of a nuclear wars betwen India and Pakistan?'
# Replacing 2 words we have a similarity of [[0.8434958]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the chance of a nuclear wars betwen India and Pakistan?'
# Replacing 3 words we have a similarity of [[0.8027473]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the chance of a atomic wars betwen India and Pakistan?'
# Replacing 4 words we have a similarity of [[0.5761683]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'What are the opportunity of a atomic wars betwen India and Pakistan?'
# Replacing 5 words we have a similarity of [[0.4113149]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'Which are the opportunity of a atomic wars betwen India and Pakistan?'
# Replacing 6 words we have a similarity of [[0.27535737]]
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'Which are the opportunity of a atomic wars betwen Indias and Pakistan?'
# Replacing 7 words we have a similarity of [[0.20124486]]
#
# q1: 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'
# q2: 'Which are this opportunity of a atomic wars betwen Indias and Pakistan?'
# Replacing 8 words we have a similarity of [[0.19914307]]
#
# initial q1: Are the IMDB ratings accurate?
# initial q2: Is IMDb rating apt?
# Initial similarity is [[0.93939286]]
#
# q1: 'Are the IMDB ratings accurate?'
# q2: 'Is IMDb ratings apt?'
# Replacing 1 words we have a similarity of [[0.91727877]]
# UNSUCCESSFULL
#
# initial q1: Where is the best videocon service center in Hyderabad?
# initial q2: Which is the best Videocon Service Center in Hyderabad?
# Initial similarity is [[0.7097009]]
#
# q1: 'Where is the best videocon service center in Hyderabad?'
# q2: 'Which is the best Videocon Service Cen_ter in Hyderabad?'
# Replacing 1 words we have a similarity of [[0.3675782]]
#
# initial q1: How can Donald Trump win the elections when people hate him so much?
# initial q2: How did Donald Trump win the 2016 Presidential Election?
# Initial similarity is [[0.83445764]]
#
# q1: 'How can Donald Trump win the elections when people hate him so much?'
# q2: 'How didn_`_t Donald Trump win the 2016 Presidential Election?'
# Replacing 1 words we have a similarity of [[0.7567834]]
#
# q1: 'How can Donald Trump win the elections when people hate him so much?'
# q2: 'How didn_`_t Donald Trump victory the 2016 Presidential Election?'
# Replacing 2 words we have a similarity of [[0.7541855]]
# UNSUCCESSFULL
#
# initial q1: Do heaven and hell really exist?
# initial q2: Is hell and heaven real?
# Initial similarity is [[0.8519228]]
#
# q1: 'Do heaven and hell really exist?'
# q2: 'Is hell and heaven genuine?'
# Replacing 1 words we have a similarity of [[0.7623895]]
#
# q1: 'Do heaven and hell really exist?'
# q2: 'Was hell and heaven genuine?'
# Replacing 2 words we have a similarity of [[0.5400697]]
#
# q1: 'Do heaven and hell really exist?'
# q2: 'Was heck and heaven genuine?'
# Replacing 3 words we have a similarity of [[0.4809487]]
# UNSUCCESSFULL
#
# initial q1: What are the best way to promote the Atithi dewo Bhawa Campaign in Nepal?
# initial q2: What are the best way to promote the Atithi Dewo Bhawa in Nepal?
# Initial similarity is [[0.7817473]]
#
# q1: 'What are the best way to promote the Atithi dewo Bhawa Campaign in Nepal?'
# q2: 'What are the best way to promote the Chashme Dewo Bhawa in Nepal?'
# Replacing 1 words we have a similarity of [[0.13245663]]
#
# initial q1: Who are the celebrities who are on Quora?
# initial q2: Who are some celebrity users of Quora?
# Initial similarity is [[0.7629602]]
#
# q1: 'Who are the celebrities who are on Quora?'
# q2: 'Who are some celebrity users of Fluther?'
# Replacing 1 words we have a similarity of [[0.5235246]]
#
# q1: 'Who are the celebrities who are on Quora?'
# q2: 'Why are some celebrity users of Fluther?'
# Replacing 2 words we have a similarity of [[0.39858672]]
#
# initial q1: Does true love exist in the world?
# initial q2: Is really true love exist?
# Initial similarity is [[0.80488986]]
#
# q1: 'Does true love exist in the world?'
# q2: 'Is really true love existed?'
# Replacing 1 words we have a similarity of [[0.71030617]]
#
# q1: 'Does true love exist in the world?'
# q2: 'Is obviously true love existed?'
# Replacing 2 words we have a similarity of [[0.6335739]]
#
# q1: 'Does true love exist in the world?'
# q2: 'Is obviously truest love existed?'
# Replacing 3 words we have a similarity of [[0.61188376]]
# UNSUCCESSFULL
#
# initial q1: Which are top classified websites in Saudi Arabia?
# initial q2: Which are top 5 classified websites in Saudi Arabia?
# Initial similarity is [[0.8061083]]
#
# q1: 'Which are top classified websites in Saudi Arabia?'
# q2: 'Which are top 5 classified websites in Saudi Wadi_Rum?'
# Replacing 1 words we have a similarity of [[0.47006452]]
#
# q1: 'Which are top classified websites in Saudi Arabia?'
# q2: 'Which were top 5 classified websites in Saudi Wadi_Rum?'
# Replacing 2 words we have a similarity of [[0.40254992]]
#
# q1: 'Which are top classified websites in Saudi Arabia?'
# q2: 'Which were top 6 classified websites in Saudi Wadi_Rum?'
# Replacing 3 words we have a similarity of [[0.37426537]]
#
# initial q1: What are the best TV serials to watch?
# initial q2: What are the top 10 best TV series of all time?
# Initial similarity is [[0.8331679]]
#
# q1: 'What are the best TV serials to watch?'
# q2: 'What are the top 10 best television series of all time?'
# Replacing 1 words we have a similarity of [[0.5095607]]
#
# q1: 'What are the best TV serials to watch?'
# q2: 'What are the top 10 best television series of these time?'
# Replacing 2 words we have a similarity of [[0.30884424]]
#
# initial q1: How can I lose 30 pounds in 30 days with a workout plan?
# initial q2: What are some ways to lose 30 pound in 1 month?
# Initial similarity is [[0.87321615]]
#
# q1: 'How can I lose 30 pounds in 30 days with a workout plan?'
# q2: 'What are many ways to lose 30 pound in 1 month?'
# Replacing 1 words we have a similarity of [[0.770945]]
#
# q1: 'How can I lose 30 pounds in 30 days with a workout plan?'
# q2: 'What were many ways to lose 30 pound in 1 month?'
# Replacing 2 words we have a similarity of [[0.6835365]]
#
# q1: 'How can I lose 30 pounds in 30 days with a workout plan?'
# q2: 'What were many ways to losing 30 pound in 1 month?'
# Replacing 3 words we have a similarity of [[0.64865243]]
#
# q1: 'How can I lose 30 pounds in 30 days with a workout plan?'
# q2: 'What were many ways to lost 30 pound in 1 month?'
# Replacing 4 words we have a similarity of [[0.53211683]]
#
# q1: 'How can I lose 30 pounds in 30 days with a workout plan?'
# q2: 'What were many way to lost 30 pound in 1 month?'
# Replacing 5 words we have a similarity of [[0.4788754]]
#
# q1: 'How can I lose 30 pounds in 30 days with a workout plan?'
# q2: 'Which were many way to lost 30 pound in 1 month?'
# Replacing 6 words we have a similarity of [[0.45381388]]
# UNSUCCESSFULL
#
# initial q1: What are some good laptop for 50k?
# initial q2: What are the best laptop buying options available under 50k?
# Initial similarity is [[0.95758444]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-520f9c09835a> in <module>()
#       3     q2 = X_test[i, 1]
#       4     if model.predict_single(q1, q2) > 0.6:
# ----> 5         adversarial_white_box_change(q1, q2, model, tp, w2v)
#       6         print()
#
# ~/src/query-similarity-detection/NLP/Quora Dataset/adversarial_algos.py in adversarial_white_box_change(q1, q2, model, tp, word_similarity, threshold)
#      21         for i, word in enumerate(q2_tokenized):
#      22             if word_similarity.contains_word(word):
# ---> 23                 closest_word = word_similarity.most_similar(word)
#      24                 q2_modified = list(q2_tokenized)
#      25                 q2_modified[i] = closest_word
#
# ~/src/query-similarity-detection/NLP/Quora Dataset/word2vec.py in most_similar(self, word)
#       9
#      10     def most_similar(self, word):
# ---> 11         return self.model.most_similar([word], topn=1)[0][0]
#      12
#      13     def most_similar_words(self, word, n):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     374
#     375         limited = self.vectors_norm if restrict_vocab is None else self.vectors_norm[:restrict_vocab]
# --> 376         dists = dot(limited, mean)
#     377         if not topn:
#     378             return dists
#
# KeyboardInterrupt:
